# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib as mpl
mpl.rcParams['figure.figsize']=(20,5)

# %%
# to handle datasets
import pandas as pd
import numpy as np

# for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# for the yeo-johnson transformation
import scipy.stats as stats

# to display all the columns of the dataframe in the notebook
pd.pandas.set_option('display.max_columns', None)

# %%
import os
os.chdir('E:/ML_Deployment/dataset')

# %%
df = pd.read_csv('train.csv')

# %%
df = df.drop('Id', axis=1)
df.shape
# Out:
# (1460, 80)

# %% [markdown]
# #Target

# %%
df['SalePrice'].plot(kind='hist', bins= 200)
plt.ylabel('Number of houses')
plt.xlabel('Sale Price')
plt.show()

# %%
df.isna().sum().sort_values(ascending=False).plot.bar()
plt.ylabel('number of na')
plt.title('na')
plt.axhline(y=1200, color= 'red')
plt.show()

# %%
var_with_na = df.columns[df.isna().sum()>0]

# %%
#df[var_with_na].isna().sum()
#[col for col in df.columns if df[col].dtypes=='int64' ]

# %%
df[['Street','LotArea']].pivot_table(columns='Street', values='LotArea', aggfunc='sum')
# Out:
# Street     Grvl      Pave
# LotArea  246818  15107751

# %%
pd.crosstab(index=df['Street'],columns=df['Street'] , values=df['LotArea'], aggfunc='sum')
# Out:
# Street      Grvl        Pave
# Street
# Grvl    246818.0         NaN
# Pave         NaN  15107751.0

# %%
df['SalePrice'].plot(kind='hist', bins=100)

# %%
var_cat = [col for col in df.columns if df[col].dtypes=='object']
var_num= [ i for i in df.columns if i not in var_cat]

# %%
def plotting(x):
    sns.boxplot(x=x, y='SalePrice', data=df)
    plt.show()
    
for i in var_cat:
    plotting(i)

# %%
df[var_num].hist(bins=30, figsize = (20,20))
plt.show()
